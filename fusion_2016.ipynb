# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.pyplot import show
import re

# %%
# xl.sheet_names
x = pd.read_excel("data/data_to_be_processed/municipalities_fusion.xls", sheetname='exportList', skiprows=13)
x = x[x['Date de l\'inscription'].str.contains(r".*201[3456]")]
x.drop([x.columns[i] for i in [0,1,2,5,6]], axis=1, inplace=True)
x.columns = ['pre_id', 'pre_name', 'post_id', 'post_name', 'date']
x.head(200)
# Out:
# WARNING *** OLE2 inconsistency: SSCS size is 0 but SSAT size is non-zero
#      pre_id                 pre_name  post_id               post_name  \
# 0       308  Niederried bei Kallnach      304                Kallnach
# 1       548             Ruppoldsried      310         Rapperswil (BE)
# 2       631                Trimstein      616               Münsingen
# 3      1003              Escholzmatt     1010     Escholzmatt-Marbach
# 4      1006             Marbach (LU)     1010     Escholzmatt-Marbach
# 5      1092                  Neudorf     1081             Beromünster
# 6      1096                Pfeffikon     1097         Rickenbach (LU)
# 7      1138                  Ohmstal     1143                  Schötz
# 8      2244                 Büchslen     2275                  Murten
# 9      2459              Nennigkofen     2464  Lüsslingen-Nennigkofen
# 10     2454               Lüsslingen     2464  Lüsslingen-Nennigkofen
# ...

# %%
#some municipalities have not fusionned on the 01.01.201**
#this could cause some problems when handling 2013 and 2016 data
t = x.loc[(x.date.str.contains('01.01') == False)]
t
# Out:
#      pre_id       pre_name  post_id           post_name        date
# 96     5130          Tegna     5396  Terre di Pedemonte  14.04.2013
# 97     5133        Verscio     5396  Terre di Pedemonte  14.04.2013
# 98     5099     Cavigliano     5396  Terre di Pedemonte  14.04.2013
# 99     5224        Sonvico     5192              Lugano  14.04.2013
# 100    5229       Valcolla     5192              Lugano  14.04.2013
# 101    5173        Certara     5192              Lugano  14.04.2013
# 102    5170         Carona     5192              Lugano  14.04.2013
# 103    5163          Cadro     5192              Lugano  14.04.2013
# 104    5174       Cimadera     5192              Lugano  14.04.2013
# 105    5155          Bogno     5192              Lugano  14.04.2013
# 106    5243        Besazio     5254           Mendrisio  14.04.2013
# 107    5255         Meride     5254           Mendrisio  14.04.2013
# 108    5253     Ligornetto     5254           Mendrisio  14.04.2013
# ...

# %%
x.to_csv('data/fusion_mappings.csv', index=False)
