# %%
import pandas as pd
import numpy as np

# %%
#data = pd.read_excel('data/je-f-17.03.03.bx.608.c.xls')
data = pd.read_excel('data/je-f-17.03.03.bx.608.k.xls')
data.head()
# Out:
#               Votation populaire du 27 novembre 2016          Unnamed: 1  \
# 0  Initiative populaire « Pour la sortie programm...                 NaN
# 1                                  No votation:  608                 NaN
# 2      résultats provisoires du dimanche de votation                 NaN
# 3                                             Canton  Electeurs inscrits
# 4                                                                    NaN
#
#           Unnamed: 2     Unnamed: 3 Unnamed: 4 Unnamed: 5          Unnamed: 6  \
# 0                NaN            NaN        NaN        NaN                 NaN
# 1                NaN            NaN        NaN        NaN                 NaN
# 2                NaN            NaN        NaN        NaN                 NaN
# 3  Bulletins rentrés  Participation     Blancs       Nuls  Bulletins valables
# 4                NaN            NaN        NaN        NaN                 NaN
#
#   Unnamed: 7 Unnamed: 8 Unnamed: 9
# ...

# %%
data =data.ix[7:32]
data
# Out:
#    Votation populaire du 27 novembre 2016 Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 7                                  Zürich     918806     421277    45.8505
# 8                            Bern / Berne     732503               43.1744
# 9                                  Luzern     273702     121374    44.3453
# 10                                    Uri      26543      10576    39.8448
# 11                                 Schwyz     103338      48725    47.1511
# 12                               Obwalden      26485      13204    49.8546
# 13                              Nidwalden      31015      15276    49.2536
# 14                                 Glarus      26348      10168    38.5912
# 15                                    Zug      75678      38597    51.0016
# 16                    Fribourg / Freiburg     198529      89858    45.2619
# 17                              Solothurn     178722      80576    45.0845
# ...

# %%
col = data.columns
data = data[[col[0], col[9]]]
data.head()
# Out:
#    Votation populaire du 27 novembre 2016 Unnamed: 9
# 7                                  Zürich    47.1317
# 8                            Bern / Berne    43.8164
# 9                                  Luzern    38.9823
# 10                                    Uri    40.4982
# 11                                 Schwyz    31.9082

# %%
data.columns = ['name', 'data']
data['id'] = range(1,27)
data.set_index(['id'])
# Out:
# /Users/baptisteraemy/anaconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                                 name     data
# id
# 1                             Zürich  47.1317
# 2                       Bern / Berne  43.8164
# 3                             Luzern  38.9823
# 4                                Uri  40.4982
# 5                             Schwyz  31.9082
# 6                           Obwalden  35.1253
# 7                          Nidwalden  34.9551
# 8                             Glarus  38.5345
# 9                                Zug   37.915
# 10               Fribourg / Freiburg  48.4979
# 11                         Solothurn  39.4742
# ...

# %%
data.to_csv('data/nucleaireCanton.csv', index=False)
